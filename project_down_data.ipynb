# %%
import geopandas as gpd

# %%
#Scrapping files from the website
import os
import requests
from datetime import datetime, timedelta

# %%
#downloading the temperature data from 2017 to the end of 2020
start_date = datetime(2017, 1, 1)
end_date = datetime(2020, 12, 31)
base_url = "https://ftp.cpc.ncep.noaa.gov/GIS/USDM_Products/temp/total/daily"
download_dir = r"C:\Users\Mahmudul Hasan\Downloads\Temfiles"
os.makedirs(download_dir, exist_ok=True)

current_date = start_date
while current_date <= end_date:
    file_name = f"t.full.1stday_month_{current_date.strftime('%Y%m%d')}.tif"
    file_url = f"{base_url}/{file_name}"
    response = requests.get(file_url)
    if response.status_code == 200:
        with open(os.path.join(download_dir, file_name), "wb") as file:
            file.write(response.content)
        print(f"Downloaded: {file_name}")
    else:
        print(f"Failed to download: {file_name}")
    current_date += timedelta(days=1)
# Out:
# Downloaded: t.full.1stday_month_20170101.tif
# Downloaded: t.full.1stday_month_20170102.tif
# Downloaded: t.full.1stday_month_20170103.tif
# Downloaded: t.full.1stday_month_20170104.tif
# Downloaded: t.full.1stday_month_20170105.tif
# Downloaded: t.full.1stday_month_20170106.tif
# Downloaded: t.full.1stday_month_20170107.tif
# Downloaded: t.full.1stday_month_20170108.tif
# Downloaded: t.full.1stday_month_20170109.tif
# Downloaded: t.full.1stday_month_20170110.tif
# Downloaded: t.full.1stday_month_20170111.tif
# Downloaded: t.full.1stday_month_20170112.tif
# Downloaded: t.full.1stday_month_20170113.tif
# Downloaded: t.full.1stday_month_20170114.tif
# Downloaded: t.full.1stday_month_20170115.tif
# Downloaded: t.full.1stday_month_20170116.tif
# Downloaded: t.full.1stday_month_20170117.tif
# Downloaded: t.full.1stday_month_20170118.tif
# Downloaded: t.full.1stday_month_20170119.tif
# Downloaded: t.full.1stday_month_20170120.tif
# Downloaded: t.full.1stday_month_20170121.tif
# ...

# %%
#downloading the precipitation data from 2017 to the end of 2020
start_date = datetime(2017, 1, 1)
end_date = datetime(2020, 12, 31)
base_url = "https://ftp.cpc.ncep.noaa.gov/GIS/USDM_Products/precip/total/daily/"
download_dir = r"C:\Users\Mahmudul Hasan\Downloads\Precipitation"
os.makedirs(download_dir, exist_ok=True)

current_date = start_date
while current_date <= end_date:
    file_name = f"p.full.1stday_month_{current_date.strftime('%Y%m%d')}.tif"
    file_url = f"{base_url}/{file_name}"
    response = requests.get(file_url)
    if response.status_code == 200:
        with open(os.path.join(download_dir, file_name), "wb") as file:
            file.write(response.content)
        print(f"Downloaded: {file_name}")
    else:
        print(f"Failed to download: {file_name}")
    current_date += timedelta(days=1)
print("Download Finished")
# Out:
# Downloaded: p.full.1stday_month_20170101.tif
# Downloaded: p.full.1stday_month_20170102.tif
# Downloaded: p.full.1stday_month_20170103.tif
# Downloaded: p.full.1stday_month_20170104.tif
# Downloaded: p.full.1stday_month_20170105.tif
# Downloaded: p.full.1stday_month_20170106.tif
# Downloaded: p.full.1stday_month_20170107.tif
# Downloaded: p.full.1stday_month_20170108.tif
# Downloaded: p.full.1stday_month_20170109.tif
# Downloaded: p.full.1stday_month_20170110.tif
# Downloaded: p.full.1stday_month_20170111.tif
# Downloaded: p.full.1stday_month_20170112.tif
# Downloaded: p.full.1stday_month_20170113.tif
# Downloaded: p.full.1stday_month_20170114.tif
# Downloaded: p.full.1stday_month_20170115.tif
# Downloaded: p.full.1stday_month_20170116.tif
# Downloaded: p.full.1stday_month_20170117.tif
# Downloaded: p.full.1stday_month_20170118.tif
# Downloaded: p.full.1stday_month_20170119.tif
# Downloaded: p.full.1stday_month_20170120.tif
# Downloaded: p.full.1stday_month_20170121.tif
# ...

# %%
#downloading the soil Moisture data data from 2017 to the end of 2020
start_date = datetime(2017, 1, 1)
end_date = datetime(2020, 12, 31)
base_url = "https://ftp.cpc.ncep.noaa.gov/GIS/USDM_Products/soil/total/daily/"
download_dir = r"C:\Users\Mahmudul Hasan\Downloads\Soilmoist"
os.makedirs(download_dir, exist_ok=True)

current_date = start_date
while current_date <= end_date:
    file_name = f"w.full.1stday_month_{current_date.strftime('%Y%m%d')}.tif"
    file_url = f"{base_url}/{file_name}"
    response = requests.get(file_url)
    if response.status_code == 200:
        with open(os.path.join(download_dir, file_name), "wb") as file:
            file.write(response.content)
        print(f"Downloaded: {file_name}")
    else:
        print(f"Failed to download: {file_name}")
    current_date += timedelta(days=1)
print("Download Finished")
